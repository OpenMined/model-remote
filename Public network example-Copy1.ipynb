# %%
from llama_remote import client

# %%
# client = client("~/.syft_bob_config.json")
client = client()
client.datasites
# Out:
# 2025-03-16 22:29:07.106 | INFO     | syft_rpc_client:__init__:46 - 🔑 Connected as: andrew@openmined.org
# DatasiteCollection(4 datasites: alice@openmined.org, amber@openmined.org, andrew@openmined.org, bob@openmined.org)

# %%
client.files
# Out:
# ['/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/syftperm.yaml',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/favourite_movies.txt',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/user_log.csv',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/training_data.txt',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_model_apis/fine_tuning_inbox/README.md',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/claudios.pkl',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/geminis.zip',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/tokenizer_weights.pkl',
# ...

# %%
my_files = ['/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/favourite_movies.txt', '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/medical_records/fit_bit_sleep_stats.csv', '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/medical_records/apple_health.csv', '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/medical_records/blood_tests.csv']

# %%
new_perms = client.manage_file_permissions(file_paths=my_files, add_users=["*"], remove_users=[])
new_perms['success']
# Out:
# 2025-03-16 22:30:15.987 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/favourite_movies.txt
# 2025-03-16 22:30:15.989 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/medical_records/fit_bit_sleep_stats.csv
# 2025-03-16 22:30:15.989 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/medical_records/apple_health.csv
# 2025-03-16 22:30:15.990 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/medical_records/blood_tests.csv
# True

# %%
me2bob = client.datasites['bob@openmined.org']

# %%
me2bob.files
# Out:
# 2025-03-16 22:31:52.487 | INFO     | llama_remote:list_accessible_files:539 - Requesting list of accessible files from bob@openmined.org
# 2025-03-16 22:31:52.489 | INFO     | syft_rpc_client:send_request:167 - 📤 SENDING: Request to bob@openmined.org
# 2025-03-16 22:32:03.498 | INFO     | syft_rpc_client:send_request:182 - 📥 RECEIVED: Response from bob@openmined.org. Time: 11.01s
# ['/Users/atrask/Desktop/SyftBoxBob/datasites/bob@openmined.org/company_data/test_data.txt',
#  '/Users/atrask/Desktop/SyftBoxBob/datasites/bob@openmined.org/company_data/financial_metrics.csv',
#  '/Users/atrask/Desktop/SyftBoxBob/datasites/bob@openmined.org/company_data/strategic_plan.txt']

# %%
my_files = ['/Users/atrask/Desktop/SyftBoxBob/datasites/bob@openmined.org/company_data/test_data.txt', '/Users/atrask/Desktop/SyftBoxBob/datasites/bob@openmined.org/company_data/financial_metrics.csv', '/Users/atrask/Desktop/SyftBoxBob/datasites/bob@openmined.org/company_data/strategic_plan.txt']

# %%
response = bob2alice.generate(
    model="llama3.2:latest",
    prompt="What is the secret number?",
    file_paths=my_files  # Include this demo file in context
)
# Out:
# 2025-03-16 22:32:24.445 | INFO     | syft_rpc_client:send_request:167 - 📤 SENDING: Request to bob@openmined.org
# 2025-03-16 22:32:36.970 | INFO     | syft_rpc_client:send_request:182 - 📥 RECEIVED: Response from bob@openmined.org. Time: 12.52s

# %%
response.response
# Out:
# 'The secret number is 23.'
