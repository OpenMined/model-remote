# %%
from llama_remote import client

# %%
client = client()
# Out:
# 2025-03-16 22:53:43.451 | INFO     | syft_rpc_client:__init__:46 - 🔑 Connected as: andrew@openmined.org

# %%
client.datasites
# Out:
# DatasiteCollection(4 datasites: alice@openmined.org, amber@openmined.org, andrew@openmined.org, bob@openmined.org)

# %%
amber = client.datasites['amber@openmined.org']

# %%
amber.generate("Hi Amber! How are you?")
# Out:
# 2025-03-16 22:54:58.800 | INFO     | syft_rpc_client:send_request:167 - 📤 SENDING: Request to amber@openmined.org
# 2025-03-16 22:55:08.795 | INFO     | syft_rpc_client:send_request:182 - 📥 RECEIVED: Response from amber@openmined.org. Time: 9.99s
# 2025-03-16 22:55:08.796 | INFO     | llama_remote:generate:1004 - Using default model: llama3.2:latest
# 2025-03-16 22:55:08.797 | INFO     | syft_rpc_client:send_request:167 - 📤 SENDING: Request to amber@openmined.org
# 2025-03-16 22:55:50.050 | INFO     | syft_rpc_client:send_request:182 - 📥 RECEIVED: Response from amber@openmined.org. Time: 41.25s
# ...

# %%
amber.generate("What is your secret number?", model="llama3.2:latest")
# Out:
# 2025-03-16 22:56:12.223 | INFO     | syft_rpc_client:send_request:167 - 📤 SENDING: Request to amber@openmined.org
# 2025-03-16 22:56:47.467 | INFO     | syft_rpc_client:send_request:182 - 📥 RECEIVED: Response from amber@openmined.org. Time: 35.24s
# OllamaResponse(model='llama3.2:latest', response="I don't have a secret number. I'm a large language model, I don't have personal secrets or numbers to share. I'm designed to provide information and assist with tasks to the best of my abilities, but I don't have personal experiences or feelings.\n\nHowever, I can generate a random number for you if you'd like! Would you like me to generate a random number between 1 and 100?", error=None, ts=datetime.datetime(2025, 3, 17, 2, 56, 42, 683152, tzinfo=TzInfo(UTC)), total_duration_ms=26507621036)

# %%
amber.files
# Out:
# 2025-03-16 22:56:56.210 | INFO     | llama_remote:list_accessible_files:539 - Requesting list of accessible files from amber@openmined.org
# 2025-03-16 22:56:56.211 | INFO     | syft_rpc_client:send_request:167 - 📤 SENDING: Request to amber@openmined.org
# 2025-03-16 22:57:08.489 | INFO     | syft_rpc_client:send_request:182 - 📥 RECEIVED: Response from amber@openmined.org. Time: 12.28s
# ['/Users/amberleightrask/Desktop/SyftBox/datasites/amber@openmined.org/secret_letter.txt',
#  '/Users/amberleightrask/Desktop/SyftBox/datasites/amber@openmined.org/public/secret_number.txt']

# %%
my_files = ['/Users/amberleightrask/Desktop/SyftBox/datasites/amber@openmined.org/secret_letter.txt', 
            '/Users/amberleightrask/Desktop/SyftBox/datasites/amber@openmined.org/public/secret_number.txt']

# %%
amber.generate("What is your secret number?", 
               model="llama3.2:latest",
               file_paths=my_files
              )
# Out:
# 2025-03-16 22:58:11.480 | INFO     | syft_rpc_client:send_request:167 - 📤 SENDING: Request to amber@openmined.org
# 2025-03-16 22:58:26.784 | INFO     | syft_rpc_client:send_request:182 - 📥 RECEIVED: Response from amber@openmined.org. Time: 15.30s
# OllamaResponse(model='llama3.2:latest', response='The secret number is 23.', error=None, ts=datetime.datetime(2025, 3, 17, 2, 58, 22, 837385, tzinfo=TzInfo(UTC)), total_duration_ms=6238003477)

# %%
client.files
# Out:
# ['/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/syftperm.yaml',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/favourite_movies.txt',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/user_log.csv',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/training_data.txt',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_model_apis/fine_tuning_inbox/README.md',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/claudios.pkl',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/geminis.zip',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/tokenizer_weights.pkl',
# ...

# %%
my_files = ['/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/claudios.pkl', '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/geminis.zip', '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/tokenizer_weights.pkl', '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/pytorch_weights.pkl', '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/forward_prop.py']

# %%
client.manage_file_permissions(file_paths=my_files,
                               add_users=["*"])
# Out:
# 2025-03-16 23:00:24.703 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/claudios.pkl
# 2025-03-16 23:00:24.706 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/geminis.zip
# 2025-03-16 23:00:24.707 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/tokenizer_weights.pkl
# 2025-03-16 23:00:24.708 | INFO     | llama_remote:manage_file_permissions:759 - Updated permissions for /Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/pytorch_weights.pkl
# ...

# %%
client.files
# Out:
# ['/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/syftperm.yaml',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/favourite_movies.txt',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/user_log.csv',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/training_data.txt',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_model_apis/fine_tuning_inbox/README.md',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/claudios.pkl',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/geminis.zip',
#  '/Users/atrask/Desktop/SyftBoxAndrew/datasites/andrew@openmined.org/fancy_ai_company/ai_models/chattygpt/tokenizer_weights.pkl',
# ...

# %%
from llama_remote import client

# %%
# client = client("~/.syft_bob_config.json")
client = client()
client.datasites

# %%
amber = client.datasites['amber@openmined.org']

# %%
amber.files

# %%
my_files = ['/Users/amberleightrask/Desktop/SyftBox/datasites/amber@openmined.org/secret_letter.txt', '/Users/amberleightrask/Desktop/SyftBox/datasites/amber@openmined.org/public/secret_number.txt']

# %%
response = amber.generate(
    model="llama3.2:latest",
    prompt="What is the secret number?",
    # file_paths=my_files  # Include this demo file in context
)

# %%
response.response

# %%
response = amber.generate(
    model="llama3.2:latest",
    prompt="What is the secret letter?",
    # file_paths=my_files  # Include this demo file in context
)

# %%
response.response
